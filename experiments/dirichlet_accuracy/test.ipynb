# %%
import pandas as pd

# %%
csv_file = "/home/tanner/Documents/repos/sri/ironmarch-archetypal/experiments/dirichlet_accuracy/trial_data.csv"

# %%
dataframe = pd.read_csv(csv_file)

# %%
dataframe[dataframe["dimensions"] == 16][dataframe["batch_size"] == 32].sort_values('error')
# Out:
#         dimensions  alpha  num_sampled  batch_size  trials     error
# 215106          16   5.00         4020          32      50  0.000900
# 215124          16   5.00         4020          32      50  0.000942
# 214704          16   5.00        16027          32      50  0.000944
# 214745          16   5.00        16027          32      50  0.000951
# 215514          16   5.00         1009          32      50  0.001008
# ...            ...    ...          ...         ...     ...       ...
# 205188          16   0.05            4           3      50  0.728324
# 33768           16   0.05            2           2      50  0.744032
# 205240          16   0.05            4           6      50  0.745155
# 33934           16   0.05            4           2      50  0.772159
# 33956           16   0.05            4           4      50  0.806699
#
# [26250 rows x 6 columns]
